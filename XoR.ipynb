# %%
import tensorflow.keras as keras
import tensorflow as tf
import numpy as np
from tensorflow.keras.utils import plot_model
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

print(tf.__version__)
# Out:
# 1.14.0

# %%
mnist = tf.keras.datasets.mnist
x_train, y_train = np.array([[0,0],[0,1],[1,0],[1,1]]), np.array([[0],[1],[1],[0]])
x_test, y_test = np.array([[0.1,0.1], [0.1,0.9], [0.9,0.1], [0.9,0.9]]), np.array([0.0,0.99,0.99,0.0])

print(x_train)
# Out:
# [[0 0]
#  [0 1]
#  [1 0]
#  [1 1]]

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(2, input_dim=2, activation="sigmoid"))
model.add(tf.keras.layers.Dense(2, input_dim=2, activation="tanh"))
model.add(tf.keras.layers.Dense(1, activation=tf.nn.sigmoid))

model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.5, momentum=0.05, decay=0.0001, nesterov=False),
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=1000)
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 0s 19ms/sample - loss: 0.7333 - acc: 0.5000
# Epoch 2/1000
# 4/4 [==============================] - 0s 752us/sample - loss: 0.7162 - acc: 0.5000
# Epoch 3/1000
# 4/4 [==============================] - 0s 376us/sample - loss: 0.7059 - acc: 0.5000
# Epoch 4/1000
# 4/4 [==============================] - 0s 251us/sample - loss: 0.7002 - acc: 0.5000
# Epoch 5/1000
# 4/4 [==============================] - 0s 251us/sample - loss: 0.6971 - acc: 0.5000
# Epoch 6/1000
# 4/4 [==============================] - 0s 376us/sample - loss: 0.6954 - acc: 0.5000
# Epoch 7/1000
# 4/4 [==============================] - 0s 503us/sample - loss: 0.6945 - acc: 0.7500
# Epoch 8/1000
# 4/4 [==============================] - 0s 501us/sample - loss: 0.6940 - acc: 0.7500
# Epoch 9/1000
# 4/4 [==============================] - 0s 752us/sample - loss: 0.6937 - acc: 0.7500
# Epoch 10/1000
# ...

# %%
val_loss, val_acc = model.evaluate(x_test, y_test)

print(model.predict(x_test))
# Out:
# 4/4 [==============================] - 0s 14ms/sample - loss: 0.0320 - acc: 0.5000
# [[0.00398371]
#  [0.97360694]
#  [0.98212284]
#  [0.00303647]]

# %%
print(history.history)
# Out:
# {'loss': [0.7332582473754883, 0.7162292003631592, 0.7058637142181396, 0.7001762986183167, 0.6970934867858887, 0.6954178810119629, 0.6944961547851562, 0.6939771175384521, 0.6936731338500977, 0.6934838891029358, 0.6933562755584717, 0.6932617425918579, 0.6931853294372559, 0.6931188106536865, 0.6930579543113708, 0.6930004954338074, 0.692945122718811, 0.6928911209106445, 0.6928383111953735, 0.6927862167358398, 0.692734956741333, 0.6926844120025635, 0.6926343441009521, 0.6925849914550781, 0.6925359964370728, 0.6924877166748047, 0.69243985414505, 0.6923924088478088, 0.6923454403877258, 0.6922990083694458, 0.6922529339790344, 0.6922072172164917, 0.6921619772911072, 0.6921170353889465, 0.6920725107192993, 0.6920282244682312, 0.6919842958450317, 0.6919406652450562, 0.6918973326683044, 0.6918542385101318, 0.6918114423751831, 0.6917687654495239, 0.6917264461517334, 0.6916843056678772, 0.6916423439979553, 0.6916005611419678, 0.6915590167045593, 0.6915175318717957, 0.6914762258529663, 0.6914349794
# ...

# %%
print(history.history.keys())


# summarize history for accuracy
plt.plot(history.history['acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'acc'])

# %%
plot_model(model, to_file='model.png', show_shapes=True)
